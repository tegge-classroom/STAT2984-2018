# %%
import matplotlib.pyplot as plt
from matplotlib.mlab import csv2rec
from matplotlib.cbook import get_sample_data

# read in data
fname = 'percent_bachelors_degrees_women_usa.csv'
gender_degree_data = csv2rec(fname)


# These are the colors that will be used in the plot
color_sequence = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c',
                  '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5',
                  '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f',
                  '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5']


majors = ['Health Professions', 'Public Administration', 'Education',
          'Psychology', 'Foreign Languages', 'English',
          'Communications\nand Journalism', 'Art and Performance', 'Biology',
          'Agriculture', 'Social Sciences and History', 'Business',
          'Math and Statistics', 'Architecture', 'Physical Sciences',
          'Computer Science', 'Engineering']

y_offsets = {'Foreign Languages': 0.5, 'English': -0.5,
             'Communications\nand Journalism': 0.75,
             'Art and Performance': -0.25, 'Agriculture': 1.25,
             'Social Sciences and History': 0.25, 'Business': -0.75,
             'Math and Statistics': 0.75, 'Architecture': -0.75,
             'Computer Science': 0.75, 'Engineering': -0.25}

# %%
# initiate figure
fig, ax = plt.subplots(1,1,figsize=(12,14))


for i in range(1,len(gender_degree_data[1])):    
    
    x = []
    y = []
    for line in gender_degree_data:
        x.append(line[0])
        y.append(line[i])
    # plot lines
    plt.plot(x,y, color = color_sequence[i-1])
    # add label
    plt.text(x[-1], y[-1] + y_offsets.get(majors[i-1], 0), majors[i-1], color=color_sequence[i-1])
    
# remove box around figure
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# add grid
plt.grid(True,'major','y')

# add title
plt.title("Here is the plot's title", fontsize=20)

plt.show()
